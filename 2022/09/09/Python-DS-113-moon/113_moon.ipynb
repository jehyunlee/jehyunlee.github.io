# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

sns.set_context("talk")
sns.set_style("ticks")
sns.set_palette("colorblind")

plt.rcParams["font.family"] = "NanumGothic"
plt.rcParams['axes.unicode_minus'] = False

# %%
moon = np.zeros((2022, 2022), dtype=int)
r = 800
for i in range(2022):
    for j in range(2022):
        d = np.sqrt(np.power(i-1011, 2) + np.power(j-1011, 2))
        if d < r:
            moon[i, j] = 255

fig, ax = plt.subplots(figsize=(5, 5), constrained_layout=True)
ax.imshow(moon)

fig.savefig("113_moon_01.png")

# %%
from scipy.ndimage import gaussian_filter
glow = gaussian_filter(moon, 30)

fig, ax = plt.subplots(figsize=(5, 5), constrained_layout=True)
ax.imshow(glow)

fig.savefig("113_moon_02.png")

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.imshow(glow, origin="upper", zorder=0, cmap="viridis")

fig.savefig("113_moon_03.png")

# %%
cmap0 = sns.color_palette("dark:y", 20)
cmap0
# Out:
# [(0.14884229104346655, 0.14884862496949566, 0.13232632559300425),
#  (0.1794895467941918, 0.17949555781418805, 0.12558027762159618),
#  (0.210136802544917, 0.2101424906588804, 0.11883422965018814),
#  (0.2431415395072365, 0.24314687987624145, 0.11156925491174868),
#  (0.27378879525796174, 0.27379381272093384, 0.10482320694034063),
#  (0.3067935322202812, 0.3067982019382949, 0.09755823220190117),
#  (0.3374407879710064, 0.3374451347829872, 0.09081218423049311),
#  (0.37044552493332594, 0.37044952400034825, 0.08354720949205366),
#  (0.4010927806840512, 0.4010964568450406, 0.0768011615206456),
#  (0.4340975176463706, 0.4341008460624016, 0.06953618678220616),
#  (0.46474477339709586, 0.46474777890709407, 0.06279013881079809),
#  (0.4977495103594153, 0.497752168124455, 0.05552516407235865),
#  (0.5283967661101405, 0.5283991009691474, 0.04877911610095059),
#  (0.5614015030724601, 0.5614034901865085, 0.04151414136251114),
#  (0.5920487588231853, 0.5920504230312008, 0.034768093391103067),
#  (0.6250534957855047, 0.6250548122485619, 0.02750311865266364),
#  (0.6557007515362301, 0.6557017450932542, 0.02075707068125557),
#  (0.6887054884985495, 0.6887061343106152, 0.013492095942816112),
#  (0.7193527442492748, 0.7193530671553076, 0.00674604797140807),
#  (0.75, 0.75, 0.0)]

# %%
cmap1 = sns.color_palette("blend:y,w", 20)
cmap1
# Out:
# [(0.75, 0.75, 0.0),
#  (0.7627450980392156, 0.7627450980392156, 0.050980392156862744),
#  (0.7754901960784314, 0.7754901960784314, 0.10196078431372549),
#  (0.7892156862745098, 0.7892156862745098, 0.1568627450980392),
#  (0.8019607843137255, 0.8019607843137255, 0.20784313725490194),
#  (0.8156862745098039, 0.8156862745098039, 0.2627450980392157),
#  (0.8284313725490196, 0.8284313725490196, 0.3137254901960784),
#  (0.842156862745098, 0.842156862745098, 0.3686274509803922),
#  (0.8549019607843137, 0.8549019607843137, 0.4196078431372549),
#  (0.8686274509803922, 0.8686274509803922, 0.4745098039215686),
#  (0.8813725490196078, 0.8813725490196078, 0.5254901960784314),
#  (0.8950980392156862, 0.8950980392156862, 0.580392156862745),
#  (0.907843137254902, 0.907843137254902, 0.6313725490196078),
#  (0.9215686274509804, 0.9215686274509804, 0.6862745098039216),
#  (0.9343137254901961, 0.9343137254901961, 0.7372549019607844),
#  (0.9480392156862745, 0.9480392156862745, 0.792156862745098),
#  (0.9607843137254902, 0.9607843137254902, 0.8431372549019608),
#  (0.9745098039215686, 0.9745098039215686, 0.8980392156862745),
#  (0.9872549019607844, 0.9872549019607844, 0.9490196078431372),
#  (1.0, 1.0, 1.0)]

# %%
from matplotlib.colors import ListedColormap

cmap = ListedColormap(cmap0 + cmap1)
cmap

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.imshow(glow, origin="upper", zorder=0, cmap=cmap)

fig.savefig("113_moon_08.png")

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.imshow(glow, origin="upper", zorder=0, cmap=cmap)
ax.imshow(np.ma.masked_array(moon, moon <1), origin="upper", zorder=0, 
          vmin=0, vmax=255, cmap=cmap, alpha=0.5)

fig.savefig("113_moon_10.png")

# %%
fig.set_size_inches((10, 10))
ax.axis(False)
fig.set_facecolor(cmap0[0])
fig.tight_layout()
fig.savefig("113_moon_09.png")
display(fig)
