# %%
# https://scipy-lectures.org/packages/scikit-learn/auto_examples/plot_eigenfaces.html

# %%
plt.rcParams['font.family']='NanumGothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from sklearn.datasets import fetch_olivetti_faces

faces_all = fetch_olivetti_faces()
K = 20

faces = faces_all.images[faces_all.target == K]

fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(10, 5))
axes = ax.ravel()

for face, axi in zip(faces, axes):
    axi.imshow(face, cmap=plt.cm.bone)
    axi.grid(False)
    axi.xaxis.set_ticks([])
    axi.yaxis.set_ticks([])

plt.subplots_adjust(top=1, bottom=0, hspace=0, wspace=0.05)
plt.tight_layout()

# %%
pca_oli = PCA(n_components=2)

faces_ori = faces_all.data[faces_all.target==K]
faces_reduced = pca_oli.fit_transform(faces_ori)
faces_recovered = pca_oli.inverse_transform(faces_reduced)

# %%
from sklearn.metrics import mean_squared_error

fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(10, 5))
axes = ax.ravel()

for face_ori, face_recovered, axi in zip(faces_ori, faces_recovered, axes):
    mse = mean_squared_error(face_ori, face_recovered)
    
    axi.imshow(face_recovered.reshape(64,64), cmap=plt.cm.bone)
    axi.set_title(f"mse={mse:1.2e}")
    axi.grid(False)
    axi.xaxis.set_ticks([])
    axi.yaxis.set_ticks([])

plt.subplots_adjust(top=1, bottom=0, hspace=0, wspace=0.05)
plt.tight_layout()

# %%
from sklearn.decomposition import PCA
pca3 = PCA(n_components=2)
X3 = faces_all.data[faces_all.target==K]
W3 = pca3.fit_transform(X3)
X32 = pca3.inverse_transform(W3)

# %%
from sklearn.metrics import mean_squared_error

# %%
fig = plt.figure(figsize=(10, 5))
plt.subplots_adjust(top=1, bottom=0, hspace=0, wspace=0.05)

for i in range(N):
    for j in range(M):
        k = i*M + j
        ax = fig.add_subplot(N, M, k+1)
        mse = mean_squared_error(X3[k], X32[k])
        ax.imshow(X32[k].reshape(64, 64), cmap=plt.cm.bone)
        ax.grid(False)
        ax.set_title(f"mse={mse:1.2e}")
        ax.xaxis.set_ticks([])
        ax.yaxis.set_ticks([])

plt.tight_layout()

# %%
face_mean = pca_oli.mean_.reshape(64, 64)
face_p1 = pca_oli.components_[0].reshape(64, 64)
face_p2 = pca_oli.components_[1].reshape(64, 64)

# %%
fig, ax = plt.subplots(ncols=3, figsize=(10, 5))
ax[0].imshow(face_mean, cmap=plt.cm.bone)
ax[0].set_title("평균 얼굴")
ax[0].grid(False)
ax[0].xaxis.set_ticks([])
ax[0].yaxis.set_ticks([])
ax[1].imshow(face_p1, cmap=plt.cm.bone)
ax[1].set_title("PC1")
ax[1].grid(False)
ax[1].xaxis.set_ticks([])
ax[1].yaxis.set_ticks([])
ax[2].imshow(face_p2, cmap=plt.cm.bone)
ax[2].set_title("PC2")
ax[2].grid(False)
ax[2].xaxis.set_ticks([])
ax[2].yaxis.set_ticks([])
plt.show()

# %%
face_mean = pca3.mean_.reshape(64, 64)
face_p1 = pca3.components_[0].reshape(64, 64)
face_p2 = pca3.components_[1].reshape(64, 64)

# %%
plt.subplot(131)
plt.imshow(face_mean, cmap=plt.cm.bone)
plt.grid(False)
plt.xticks([])
plt.yticks([])
plt.title("평균 얼굴")
plt.subplot(132)
plt.imshow(face_p1, cmap=plt.cm.bone)
plt.grid(False)
plt.xticks([])
plt.yticks([])
plt.title("주성분 1")
plt.subplot(133)
plt.imshow(face_p2, cmap=plt.cm.bone)
plt.grid(False)
plt.xticks([])
plt.yticks([])
plt.title("주성분 2")
plt.show()

# %%
N = 2
M = 5
fig = plt.figure(figsize=(10, 5))
plt.subplots_adjust(top=1, bottom=0, hspace=0, wspace=0.05)
for i in range(N):
    for j in range(M):
        k = i * M + j
        ax = fig.add_subplot(N, M, k+1)
        w = 1.5 * (k - 5) if k < 5 else 1.5 * (k - 4)
        ax.imshow(face_mean + w * face_p1, cmap=plt.cm.bone)
        ax.grid(False)
        ax.xaxis.set_ticks([])
        ax.yaxis.set_ticks([])
        plt.title("PC1 가중치={}".format(w))
plt.suptitle("평균 얼굴에 PC1을 더한 사진")
plt.tight_layout()
plt.show()

# %%
N = 2
M = 5
fig = plt.figure(figsize=(10, 5))
plt.subplots_adjust(top=1, bottom=0, hspace=0, wspace=0.05)
for i in range(N):
    for j in range(M):
        k = i * M + j
        ax = fig.add_subplot(N, M, k+1)
        w = 1.5 * (k - 5) if k < 5 else 1.5 * (k - 4)
        ax.imshow(face_mean + w * face_p2, cmap=plt.cm.bone)
        ax.grid(False)
        ax.xaxis.set_ticks([])
        ax.yaxis.set_ticks([])
        plt.title("PC2 가중치={:.1f}".format(w))
plt.suptitle("평균 얼굴에 PC2를 더한 사진")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
pd.core.common.is_list_like
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-fd1944cde11b> in <module>
#       1 import pandas as pd
# ----> 2 pd.core.common.is_list_like
#
# AttributeError: module 'pandas.core.common' has no attribute 'is_list_like'

# %%
import pandas_datareader.data as web
import datetime

symbols = [
    "SPASTT01USM661N", # US: 미국
    "SPASTT01JPM661N", # JP: 일본
    "SPASTT01EZM661N", # EZ: 유럽
    "SPASTT01KRM661N", # KR: 한국
]

data = pd.DataFrame()
for sym in symbols:
    data[sym] = web.DataReader(sym, data_source='fred', 
                               start=datetime.datetime(1998, 1, 1),
                               end=datetime.datetime(2019, 12, 31))[sym]

# %%
data.columns = ["US", "JP", "EZ", "KR"]
data = data / data.iloc[0] * 100

styles = ["b-.", "g--", "c:", "r-"]
data.plot(style=styles)
plt.title("세계 주요국의 20년간의 주가")
plt.show()

# %%
data
# Out:
#                     US          JP          EZ          KR
# DATE
# 1998-01-01  100.000000  100.000000  100.000000  100.000000
# 1998-02-01  105.558684  104.762612  107.520788  110.512583
# 1998-03-01  111.220340  104.364834  118.014321  110.049659
# 1998-04-01  114.662908  100.848374  126.572835   93.472772
# 1998-05-01  113.950925  100.201365  129.253665   74.976854
# ...                ...         ...         ...         ...
# 2019-08-01  236.925823  123.888985  155.149732  409.050164
# 2019-09-01  243.886086  130.586847  162.018971  430.433044
# 2019-10-01  243.068909  133.418336  163.356719  434.186937
# 2019-11-01  252.154845  139.956921  169.999799  447.939988
# 2019-12-01  257.429352  142.312231  171.324746  452.670230
#
# [264 rows x 4 columns]

# %%
(data.pct_change()+1).resample("A").prod()
# Out:
#                   US        JP        EZ        KR
# DATE
# 1998-12-31  1.142493  0.914321  1.213080  1.104116
# 1999-12-31  1.108004  1.478026  1.368723  1.876239
# 2000-12-31  1.010942  0.816344  1.013753  0.530249
# 2001-12-31  0.903618  0.761726  0.781429  1.276440
# 2002-12-31  0.823192  0.830760  0.693522  1.044482
# 2003-12-31  1.231353  1.196281  1.120661  1.151211
# 2004-12-31  1.142337  1.099459  1.105520  1.090911
# 2005-12-31  1.091355  1.449120  1.229950  1.533819
# 2006-12-31  1.166698  1.021137  1.195846  1.059538
# 2007-12-31  1.079472  0.915106  1.064021  1.339254
# 2008-12-31  0.563073  0.550706  0.528393  0.586589
# 2009-12-31  1.298204  1.077461  1.233849  1.478399
# 2010-12-31  1.093418  1.001387  1.023262  1.215092
# 2011-12-31  0.944568  0.817788  0.803692  0.928625
# 2012-12-31  1.130108  1.113441  1.169442  1.061621
# 2013-12-31  1.212996  1.541986  1.174643  1.006953
# 2014-12-31  1.066099  1.122932  1.049235  0.975377
# ...

# %%
df = ((data.pct_change() + 1).resample("A").prod() - 1).T * 100
print(df.iloc[:, :5])
# Out:
# DATE  1998-12-31  1999-12-31  2000-12-31  2001-12-31  2002-12-31
# US     14.249290   10.800392    1.094171   -9.638213  -17.680773
# JP     -8.567915   47.802619  -18.365577  -23.827406  -16.923968
# EZ     21.308040   36.872314    1.375330  -21.857080  -30.647772
# KR     10.411582   87.623876  -46.975114   27.644005    4.448180

# %%
df.T.plot(style=styles)
plt.title("주요국의 과거 20년간 연간수익률")
plt.xticks(df.columns)
plt.show()

# %%
pca2 = PCA(n_components=1)
w = pca2.fit_transform(df)

# %%
pca2.explained_variance_ratio_
# Out:
# array([0.67749102])

# %%
m = pca2.mean_

# %%
m
# Out:
# array([  9.35024903,  45.7748003 , -15.71779759,  -6.91967355,
#        -15.20108361,  17.48765584,  10.95568389,  32.60609686,
#         11.08048721,   9.94632162, -44.28095456,  27.19782058,
#          8.32897696, -12.63319273,  11.86532327,  23.41445161,
#          5.34108071,   3.42888451,   2.14468408,  17.2613721 ,
#        -13.21742621,  13.2326573 ])

# %%
p1 = pca2.components_[0]

# %%
import numpy as np

xrange = np.linspace(1998, 2019, 22, dtype=int)
for i in np.linspace(0, 110, 5):
    plt.plot(xrange, pca2.mean_ + p1 * i)
plt.plot(xrange, pca2.mean_ + p1 * 100, label="주성분의 100배를 추가한 수익률")
plt.plot(xrange, pca2.mean_, "ko-", lw=5, label="평균 수익률")
plt.title("주성분 크기에 의한 주가수익률의 변화")
plt.legend()
plt.show()

# %%
df_w = pd.DataFrame(w)
df_w.index = df.index
df_w.columns = ["주성분 비중"]
print(df_w)
# Out:
#        주성분 비중
# US -34.139709
# JP -20.080437
# EZ -27.589206
# KR  81.809353

# %%
df_i = pd.DataFrame(pca2.inverse_transform(w))
df_i.index = df.index
df_i.columns = df.columns
df_i.iloc[:, -10:]
df_i.T.plot(style=styles)
plt.title("주성분을 사용한 주요국의 과거 20년간 연간수익률 근사치")
plt.xticks(df.columns)
plt.show()
