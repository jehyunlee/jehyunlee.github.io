# %%
from copy import deepcopy
import pandas as pd
from pybliometrics.scopus import ScopusSearch
from pybliometrics.scopus import AbstractRetrieval

# %%
s_sample = ScopusSearch('TITLE-ABS-KEY ( "Photovoltaic" OR "BIPV" OR "PV" OR "Irradiation") AND \
                         TITLE-ABS-KEY ( "solar" OR "sun") AND \
                 TITLE-ABS-KEY ( "rooftop" OR "roof" OR "top") AND \
                 TITLE-ABS-KEY ( "machine learning" OR "prediction" OR "modeling" ) AND \
                 ( EXCLUDE ( SUBJAREA , "MATE" ) OR EXCLUDE ( SUBJAREA , "CHEM" ) OR EXCLUDE ( SUBJAREA , "CENG" ) ) AND ( EXCLUDE ( SUBJAREA , "MEDI" ) OR EXCLUDE ( SUBJAREA , "SOCI" ) OR EXCLUDE ( SUBJAREA , "AGRI" ) OR EXCLUDE ( SUBJAREA , "BIOC" ) OR EXCLUDE ( SUBJAREA , "BUSI" ) OR EXCLUDE ( SUBJAREA , "ECON" ) OR EXCLUDE ( SUBJAREA , "IMMU" ) OR EXCLUDE ( SUBJAREA , "NEUR" ) OR EXCLUDE ( SUBJAREA , "PHAR" ) OR EXCLUDE ( SUBJAREA , "HEAL" ) OR EXCLUDE ( SUBJAREA , "PSYC" ) OR EXCLUDE ( SUBJAREA , "ARTS" ) OR EXCLUDE ( SUBJAREA , "VETE" ) OR EXCLUDE ( SUBJAREA , "NURS" ) OR EXCLUDE ( SUBJAREA , "DENT" ) OR EXCLUDE ( SUBJAREA , "Undefined" ) ) ', 
                 download=True, verbose=True)
print(s_sample.get_results_size())
# Out:
# Downloading results for query "TITLE-ABS-KEY ( "Photovoltaic" OR "BIPV" OR "PV" OR "Irradiation") AND                          TITLE-ABS-KEY ( "solar" OR "sun") AND                  TITLE-ABS-KEY ( "rooftop" OR "roof" OR "top") AND                  TITLE-ABS-KEY ( "machine learning" OR "prediction" OR "modeling" ) AND                  ( EXCLUDE ( SUBJAREA , "MATE" ) OR EXCLUDE ( SUBJAREA , "CHEM" ) OR EXCLUDE ( SUBJAREA , "CENG" ) ) AND ( EXCLUDE ( SUBJAREA , "MEDI" ) OR EXCLUDE ( SUBJAREA , "SOCI" ) OR EXCLUDE ( SUBJAREA , "AGRI" ) OR EXCLUDE ( SUBJAREA , "BIOC" ) OR EXCLUDE ( SUBJAREA , "BUSI" ) OR EXCLUDE ( SUBJAREA , "ECON" ) OR EXCLUDE ( SUBJAREA , "IMMU" ) OR EXCLUDE ( SUBJAREA , "NEUR" ) OR EXCLUDE ( SUBJAREA , "PHAR" ) OR EXCLUDE ( SUBJAREA , "HEAL" ) OR EXCLUDE ( SUBJAREA , "PSYC" ) OR EXCLUDE ( SUBJAREA , "ARTS" ) OR EXCLUDE ( SUBJAREA , "VETE" ) OR EXCLUDE ( SUBJAREA , "NURS" ) OR EXCLUDE ( SUBJAREA , "DENT" ) OR EXCLUDE ( SUBJAREA , "Undefined" ) ) ":
# Progress: |██████████████████████████████████████████████████| 100.00% Complete
# 1028

# %%
df_sample = pd.DataFrame(s_sample.results)
df_sample.to_pickle("./df_sample.pkl")
print(df_sample.shape)
df_sample.head(3)
# Out:
# (1028, 34)
#                   eid                             doi                pii  \
# 0  2-s2.0-85125145796      10.1016/j.egyr.2022.02.088  S2352484722003353
# 1  2-s2.0-85123676147      10.1016/j.egyr.2022.01.105  S2352484722001056
# 2  2-s2.0-85124409874  10.1016/j.engappai.2022.104707  S0952197622000288
#
#   pubmed_id                                              title subtype  \
# 0      None  Data driven approach to forecast the next day ...      ar
# 1      None  Energy modeling and photovoltaics integration ...      ar
# 2      None  Multi-quantile recurrent neural network for fe...      ar
#
#   subtypeDescription          creator                          afid  \
# 0            Article        Fentis A.  60017798;127756529;116607338
# 1            Article  Al Huneidi D.I.                      60113885
# 2            Article       Zhang X.Y.             60020595;60001455
#
#                                            affilname  ... issueIdentifier  \
# 0  Faculté des Sciences et Techniques de Mohammed...  ...            None
# 1  Hamad Bin Khalifa University, College of Scien...  ...            None
# 2  Royal Holloway, University of London;Anhui Uni...  ...            None
#
#   article_number  pageRange  \
# 0           None  3221-3233
# 1           None    166-171
# 2         104707       None
#
#                                          description  \
# 0  Photovoltaic (PV) power has became an attracti...
# 1  Due to Qatar's increasing population and elect...
# 2  The purpose of feeder-level energy disaggregat...
#
#                                         authkeywords citedby_count openaccess  \
# 0  Machine learning | PV power forecasting | Rene...             0          1
# 1  Climate change | Demand side management | Desi...             1          1
# 2  Behind-the-meter PV generation | Deep neural n...             0          0
#
#   fund_acr              fund_no                  fund_sponsor
# 0     None            undefined                          None
# 1     QNRF  NPRP12S-0212-190073  Qatar National Research Fund
# 2     None            undefined                          None
#
# [3 rows x 34 columns]
